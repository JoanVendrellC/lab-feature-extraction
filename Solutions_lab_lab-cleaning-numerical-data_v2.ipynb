# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
customer_df = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')
customer_df.head(60)
# Out:
#    Customer       State  Customer Lifetime Value Response  Coverage  \
# 0   BU79786  Washington              2763.519279       No     Basic
# 1   QZ44356     Arizona              6979.535903       No  Extended
# 2   AI49188      Nevada             12887.431650       No   Premium
# 3   WW63253  California              7645.861827       No     Basic
# 4   HB64268  Washington              2813.692575       No     Basic
# 5   OC83172      Oregon              8256.297800      Yes     Basic
# 6   XZ87318      Oregon              5380.898636      Yes     Basic
# 7   CF85061     Arizona              7216.100311       No   Premium
# 8   DY87989      Oregon             24127.504020      Yes     Basic
# 9   BQ94931      Oregon              7388.178085       No  Extended
# 10  SX51350  California              4738.992022       No     Basic
# 11  VQ65197  California              8197.197078       No     Basic
# 12  DP39365  California              8798.797003       No   Premium
# ...

# %%
customer_df.shape
# Out:
# (9134, 24)

# %%
customer_df.isna().sum()/len(customer_df)
# Out:
# Customer                         0.0
# State                            0.0
# Customer Lifetime Value          0.0
# Response                         0.0
# Coverage                         0.0
# Education                        0.0
# Effective To Date                0.0
# EmploymentStatus                 0.0
# Gender                           0.0
# Income                           0.0
# Location Code                    0.0
# Marital Status                   0.0
# Monthly Premium Auto             0.0
# Months Since Last Claim          0.0
# Months Since Policy Inception    0.0
# Number of Open Complaints        0.0
# Number of Policies               0.0
# Policy Type                      0.0
# Policy                           0.0
# Renew Offer Type                 0.0
# Sales Channel                    0.0
# Total Claim Amount               0.0
# Vehicle Class                    0.0
# Vehicle Size                     0.0
# dtype: float64

# %%
customer_df.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Response', 'Coverage',
#        'Education', 'Effective To Date', 'EmploymentStatus', 'Gender',
#        'Income', 'Location Code', 'Marital Status', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies', 'Policy Type',
#        'Policy', 'Renew Offer Type', 'Sales Channel', 'Total Claim Amount',
#        'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
customer_df.dtypes
# Out:
# Customer                          object
# State                             object
# Customer Lifetime Value          float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints          int64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Renew Offer Type                  object
# Sales Channel                     object
# Total Claim Amount               float64
# Vehicle Class                     object
# ...

# %%
for e in customer_df.columns:
    print(e)
# Out:
# Customer
# State
# Customer Lifetime Value
# Response
# Coverage
# Education
# Effective To Date
# EmploymentStatus
# Gender
# Income
# Location Code
# Marital Status
# Monthly Premium Auto
# Months Since Last Claim
# Months Since Policy Inception
# Number of Open Complaints
# Number of Policies
# Policy Type
# Policy
# Renew Offer Type
# Sales Channel
# Total Claim Amount
# Vehicle Class
# Vehicle Size

# %%
customer_df.columns=[e.lower().replace(' ', '_') for e in customer_df.columns]

# %%
customer_df.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size'],
#       dtype='object')

# %%
customer_df['effective_to_date'] = pd.to_datetime(customer_df['effective_to_date'], errors='coerce')

# %%
customer_df.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   effective_to_date employmentstatus gender  income  ...  \
# 0        2011-02-24         Employed      F   56274  ...
# 1        2011-01-31       Unemployed      F       0  ...
# 2        2011-02-19         Employed      F   48767  ...
# 3        2011-01-20       Unemployed      M       0  ...
# 4        2011-02-03         Employed      M   43836  ...
#
#   months_since_policy_inception number_of_open_complaints  number_of_policies  \
# ...

# %%
customer_df_categorical=customer_df.select_dtypes(object)
customer_df_categorical
# Out:
#      customer       state response  coverage education employmentstatus  \
# 0     BU79786  Washington       No     Basic  Bachelor         Employed
# 1     QZ44356     Arizona       No  Extended  Bachelor       Unemployed
# 2     AI49188      Nevada       No   Premium  Bachelor         Employed
# 3     WW63253  California       No     Basic  Bachelor       Unemployed
# 4     HB64268  Washington       No     Basic  Bachelor         Employed
# ...       ...         ...      ...       ...       ...              ...
# 9129  LA72316  California       No     Basic  Bachelor         Employed
# 9130  PK87824  California      Yes  Extended   College         Employed
# 9131  TD14365  California       No  Extended  Bachelor       Unemployed
# 9132  UP19263  California       No  Extended   College         Employed
# 9133  Y167826  California       No  Extended   College       Unemployed
#
#      gender location_code marital_status     policy_type        policy  \
# ...

# %%
customer_df_categorical=customer_df_categorical.drop(columns=['customer'])
customer_df_categorical

#df=df.drop(columns=['unnamed:_0'])
# Out:
#            state response  coverage education employmentstatus gender  \
# 0     Washington       No     Basic  Bachelor         Employed      F
# 1        Arizona       No  Extended  Bachelor       Unemployed      F
# 2         Nevada       No   Premium  Bachelor         Employed      F
# 3     California       No     Basic  Bachelor       Unemployed      M
# 4     Washington       No     Basic  Bachelor         Employed      M
# ...          ...      ...       ...       ...              ...    ...
# 9129  California       No     Basic  Bachelor         Employed      M
# 9130  California      Yes  Extended   College         Employed      F
# 9131  California       No  Extended  Bachelor       Unemployed      M
# 9132  California       No  Extended   College         Employed      M
# 9133  California       No  Extended   College       Unemployed      M
#
#      location_code marital_status     policy_type        policy  \
# ...

# %%
customer_df_numerical=customer_df.select_dtypes(np.number)
customer_df_numerical
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %%
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

correlations_matrix = customer_df_numerical.corr()
sns.heatmap(correlations_matrix, annot=True)
plt.show()

# %%
for column in customer_df_numerical.columns:
    sns.distplot(customer_df_numerical[column])
    plt.show()
# Out:
# C:\Users\joanv\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\joanv\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
for column in customer_df_categorical.columns:
    sns.countplot(customer_df_categorical[column])
    plt.show()
# Out:
# C:\Users\joanv\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\joanv\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\joanv\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
for column in customer_df_numerical.columns:
    sns.boxplot(customer_df_numerical[column], data=customer_df_numerical[column])
    plt.show()
# Out:
# C:\Users\joanv\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\joanv\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\joanv\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
customer_df_numerical.isna().sum()
# Out:
# customer_lifetime_value          0
# income                           0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# total_claim_amount               0
# dtype: int64

# %%
customer_df_categorical
# Out:
#            state response  coverage education employmentstatus gender  \
# 0     Washington       No     Basic  Bachelor         Employed      F
# 1        Arizona       No  Extended  Bachelor       Unemployed      F
# 2         Nevada       No   Premium  Bachelor         Employed      F
# 3     California       No     Basic  Bachelor       Unemployed      M
# 4     Washington       No     Basic  Bachelor         Employed      M
# ...          ...      ...       ...       ...              ...    ...
# 9129  California       No     Basic  Bachelor         Employed      M
# 9130  California      Yes  Extended   College         Employed      F
# 9131  California       No  Extended  Bachelor       Unemployed      M
# 9132  California       No  Extended   College         Employed      M
# 9133  California       No  Extended   College       Unemployed      M
#
#      location_code marital_status     policy_type        policy  \
# ...

# %%
#LAB 2 lab-cleaning-categorical-data

# %%
#Import the necessary libraries if you are starting a new notebook. Using the same data as the previous lab: we_fn_use_c_marketing_customer_value_analysis.csv

#Find all of the categorical data. Save it in a categorical_df variable.

#Check for NaN values.

#Check all unique values of columns.

#Check dtypes. Do they all make sense as categorical data?

#Does any column contain alpha and numeric data? Decide how to clean it.

#Would you choose to do anything else to clean or wrangle the categorical data? Comment your decisions.

#Compare policy_type and policy. What information is contained in these columns. Can you identify what is important?

#Check number of unique values in each column, can they be combined in any way to ease encoding? Comment your thoughts and make those changes.

# %%
customer_df_categorical2=customer_df.select_dtypes(object)
customer_df_categorical2
# Out:
#      customer       state response  coverage education employmentstatus  \
# 0     BU79786  Washington       No     Basic  Bachelor         Employed
# 1     QZ44356     Arizona       No  Extended  Bachelor       Unemployed
# 2     AI49188      Nevada       No   Premium  Bachelor         Employed
# 3     WW63253  California       No     Basic  Bachelor       Unemployed
# 4     HB64268  Washington       No     Basic  Bachelor         Employed
# ...       ...         ...      ...       ...       ...              ...
# 9129  LA72316  California       No     Basic  Bachelor         Employed
# 9130  PK87824  California      Yes  Extended   College         Employed
# 9131  TD14365  California       No  Extended  Bachelor       Unemployed
# 9132  UP19263  California       No  Extended   College         Employed
# 9133  Y167826  California       No  Extended   College       Unemployed
#
#      gender location_code marital_status     policy_type        policy  \
# ...

# %%
customer_df_categorical2.isna().sum()
# Out:
# customer            0
# state               0
# response            0
# coverage            0
# education           0
# employmentstatus    0
# gender              0
# location_code       0
# marital_status      0
# policy_type         0
# policy              0
# renew_offer_type    0
# sales_channel       0
# vehicle_class       0
# vehicle_size        0
# dtype: int64

# %%
customer_df_categorical2.customer.value_counts(dropna=False)
# Out:
# BU79786    1
# PU81096    1
# CO75086    1
# WW52683    1
# XO38850    1
#           ..
# HS14476    1
# YL91587    1
# CT18212    1
# EW35231    1
# Y167826    1
# Name: customer, Length: 9134, dtype: int64

# %%
customer_df_categorical2.state.value_counts(dropna=False)
# Out:
# California    3150
# Oregon        2601
# Arizona       1703
# Nevada         882
# Washington     798
# Name: state, dtype: int64

# %%
customer_df_categorical2.response.value_counts(dropna=False)
# Out:
# No     7826
# Yes    1308
# Name: response, dtype: int64

# %%
customer_df_categorical2.coverage.value_counts(dropna=False)
# Out:
# Basic       5568
# Extended    2742
# Premium      824
# Name: coverage, dtype: int64

# %%
customer_df_categorical2.education.value_counts(dropna=False)
# Out:
# Bachelor                2748
# College                 2681
# High School or Below    2622
# Master                   741
# Doctor                   342
# Name: education, dtype: int64

# %%
customer_df_categorical2.employmentstatus.value_counts(dropna=False)
# Out:
# Employed         5698
# Unemployed       2317
# Medical Leave     432
# Disabled          405
# Retired           282
# Name: employmentstatus, dtype: int64

# %%
customer_df_categorical2.gender.value_counts(dropna=False)
# Out:
# F    4658
# M    4476
# Name: gender, dtype: int64

# %%
customer_df_categorical2.location_code.value_counts(dropna=False)
# Out:
# Suburban    5779
# Rural       1773
# Urban       1582
# Name: location_code, dtype: int64

# %%
customer_df_categorical2.marital_status.value_counts(dropna=False)
# Out:
# Married     5298
# Single      2467
# Divorced    1369
# Name: marital_status, dtype: int64

# %%
customer_df_categorical2.policy_type.value_counts(dropna=False)
# Out:
# Personal Auto     6788
# Corporate Auto    1968
# Special Auto       378
# Name: policy_type, dtype: int64

# %%
customer_df_categorical2.policy.value_counts(dropna=False)
# Out:
# Personal L3     3426
# Personal L2     2122
# Personal L1     1240
# Corporate L3    1014
# Corporate L2     595
# Corporate L1     359
# Special L2       164
# Special L3       148
# Special L1        66
# Name: policy, dtype: int64

# %%
customer_df_categorical2.renew_offer_type.value_counts(dropna=False)
# Out:
# Offer1    3752
# Offer2    2926
# Offer3    1432
# Offer4    1024
# Name: renew_offer_type, dtype: int64

# %%
customer_df_categorical2.sales_channel.value_counts(dropna=False)
# Out:
# Agent          3477
# Branch         2567
# Call Center    1765
# Web            1325
# Name: sales_channel, dtype: int64

# %%
customer_df_categorical2.vehicle_class.value_counts(dropna=False)
# Out:
# Four-Door Car    4621
# Two-Door Car     1886
# SUV              1796
# Sports Car        484
# Luxury SUV        184
# Luxury Car        163
# Name: vehicle_class, dtype: int64

# %%
customer_df_categorical2.vehicle_size.value_counts(dropna=False)
# Out:
# Medsize    6424
# Small      1764
# Large       946
# Name: vehicle_size, dtype: int64

# %%
customer_df_categorical2.dtypes
# Out:
# customer            object
# state               object
# response            object
# coverage            object
# education           object
# employmentstatus    object
# gender              object
# location_code       object
# marital_status      object
# policy_type         object
# policy              object
# renew_offer_type    object
# sales_channel       object
# vehicle_class       object
# vehicle_size        object
# dtype: object

# %%
customer_df_categorical2.policy_type.value_counts(dropna=False)
# Out:
# Personal Auto     6788
# Corporate Auto    1968
# Special Auto       378
# Name: policy_type, dtype: int64

# %%
customer_df_categorical2.policy.value_counts(dropna=False)
# Out:
# Personal L3     3426
# Personal L2     2122
# Personal L1     1240
# Corporate L3    1014
# Corporate L2     595
# Corporate L1     359
# Special L2       164
# Special L3       148
# Special L1        66
# Name: policy, dtype: int64

# %%
#Lab | Feature extraction

# %%
customer_df_categorical2
# Out:
#      customer       state response  coverage education employmentstatus  \
# 0     BU79786  Washington       No     Basic  Bachelor         Employed
# 1     QZ44356     Arizona       No  Extended  Bachelor       Unemployed
# 2     AI49188      Nevada       No   Premium  Bachelor         Employed
# 3     WW63253  California       No     Basic  Bachelor       Unemployed
# 4     HB64268  Washington       No     Basic  Bachelor         Employed
# ...       ...         ...      ...       ...       ...              ...
# 9129  LA72316  California       No     Basic  Bachelor         Employed
# 9130  PK87824  California      Yes  Extended   College         Employed
# 9131  TD14365  California       No  Extended  Bachelor       Unemployed
# 9132  UP19263  California       No  Extended   College         Employed
# 9133  Y167826  California       No  Extended   College       Unemployed
#
#      gender location_code marital_status     policy_type        policy  \
# ...

# %%
for column in customer_df_categorical.columns:
    sns.countplot(customer_df_categorical[column])
    plt.show()
# Out:
# C:\Users\joanv\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\joanv\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\joanv\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
#There might be some columns that seem to be redundant, check their values to be sure. What should we do with them?

# For example, the column policy has the same information than policy_type column. In this case, we can dropp the column 'policy'.
# Also, we can dropp the 'customer' column because we have an index.

# %%
 #Plot time variable. Can you extract something from it?
    
customer_df.plot( 'effective_to_date' , 'number_of_policies' )
plt.show()

# %%
customer_df.plot( 'effective_to_date' , 'income' )
plt.show()

# %%
# We cannot extract any conclusion with these times plots.
